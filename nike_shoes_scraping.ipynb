# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:81.0) Gecko/20100101 Firefox/81.0',
    'Accept': 'image/webp,*/*',
    'Accept-Language': 'fr,fr-FR;q=0.8,en-US;q=0.5,en;q=0.3',
    'Connection': 'keep-alive',
    'Pragma': 'no-cache',
    'Cache-Control': 'no-cache',
}

def individual_shoe_links():
    nike_home_links=['https://www.nike.com/in/w/retro-running-8kemk','https://www.nike.com/in/w/womens-shoes-5e1x6zy7ok']
    shoe_links=set()
    for link in nike_home_links:
        response = requests.get(link, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        product_cards = soup.find_all('div',attrs={'class':'product-card__body'})
        for card in product_cards:
            shoe_links.add(card.find('a')['href'])
    return shoe_links


def get_individual_shoe_details(link):
    def get_shoe_name(soup):
        return soup.find('h1',attrs={"id":'pdp_product_title'}).text.strip()

    def get_category(soup):
        return "Women" if "women" in soup.find('h2').text.strip().lower() else "Men"

    def get_style_or_product_code(soup):
        return soup.select_one('.description-preview__style-color').text.strip()

    def get_reviews(data):
        return data['props']['pageProps']['initialState']['reviews']['total']

    def get_sizes(data):
        sizes = set()
        for _, details in data['props']['pageProps']['initialState']['Threads']['products'].items():
            for sku in details['skus']:
                sizes.add(sku['nikeSize'])
            break
        return sizes

    def get_colors(soup):
        colorway_divs = soup.find_all('div', class_='colorway-container')
        alt_texts = []
        for div in colorway_divs:
            img_tag = div.find('img')
            if img_tag and 'alt' in img_tag.attrs:
                alt_text = img_tag['alt']
                alt_texts.append(alt_text)
        return alt_texts

    def get_star_count(data): 
        return data['props']['pageProps']['initialState']['reviews']['averageRating']

    def get_price(data):
        price = ""
        for _, details in data['props']['pageProps']['initialState']['Threads']['products'].items():
            price = details['fullPrice']
            break
        return price

    def get_dimensions(data):
        fitness = 0
        comfort = 0
        recommend = 0
        for dim in data['props']['pageProps']['initialState']['reviews']["dimensions"]:
            if dim['label'] == "How did this product fit?":
                fitness = dim["average"]
            elif dim['label'] == "How comfortable was this product?":
                comfort = dim["average"]
            elif dim['label'] == "Would you recommend this product?":
                recommend = dim["average"]
        return fitness, comfort, recommend
    link_detail = {"link": link, "brand": "nike"}
    response = requests.get(link, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    data = json.loads(soup.find('script', id='__NEXT_DATA__').text)
    link_detail["shoe_name"] =  get_shoe_name(soup)
    link_detail["category"] = get_category(soup)
    link_detail["style_or_product_code"] = get_style_or_product_code(soup)
    link_detail["reviews"] = get_reviews(data)
    available_sizes = get_sizes(data)
    link_detail["number_of_sizes"] = len(available_sizes)
    link_detail["size"] = ",".join(available_sizes)
    colors_available = get_colors(soup)
    link_detail["number_of_colors"] = len(colors_available)
    link_detail["color_1"], link_detail["color_2"], link_detail["color_3"], link_detail["color_4"], link_detail["color_5"] = (colors_available + [None] * (5 - len(colors_available)))[:5]
    link_detail["stars"] = get_star_count(data)
    link_detail["price"] = get_price(data)
    link_detail["fitness"], link_detail["comfort"], link_detail["recommend"] = get_dimensions(data)
    return link_detail

def get_nike_details():
    shoe_links = individual_shoe_links()
    details = []
    for shoe_link in shoe_links:
        details.append(get_individual_shoe_details(shoe_link))
    return details


nike_details = get_nike_details()
print(nike_details)
# Out:
# [{'link': 'https://www.nike.com/in/t/cortez-23-shoes-1VrCHW/FB6877-001', 'brand': 'nike', 'shoe_name': 'Nike Cortez 23 Premium', 'category': 'Women', 'style_or_product_code': 'Style: FB6877-001', 'reviews': 0, 'number_of_sizes': 11, 'size': '6,5,9,9.5,7,6.5,7.5,8,10,5.5,8.5', 'number_of_colors': 0, 'color_1': None, 'color_2': None, 'color_3': None, 'color_4': None, 'color_5': None, 'stars': 0, 'price': 9695, 'fitness': None, 'comfort': None, 'recommend': None}, {'link': 'https://www.nike.com/in/t/p-6000-shoes-6l9ww7/FQ8243-025', 'brand': 'nike', 'shoe_name': 'Nike P-6000 Premium', 'category': 'Men', 'style_or_product_code': 'Style: FQ8243-025', 'reviews': 9, 'number_of_sizes': 13, 'size': '12,9,9.5,12.5,7,7.5,8,10,10.5,11.5,13,11,8.5', 'number_of_colors': 0, 'color_1': None, 'color_2': None, 'color_3': None, 'color_4': None, 'color_5': None, 'stars': 5, 'price': 10795, 'fitness': None, 'comfort': None, 'recommend': None}, {'link': 'https://www.nike.com/in/t/air-jordan-1-low-se-shoes-4Kxpk4/FB9893-600', 'brand': 'nike', 'shoe_name': 'Air Jordan 1 Low SE', 'category': 'Women', 'style_or_product_code': 'Style: FB9893-600', 'reviews': 9, 'number_of_sizes': 11, 'size': '6,5,9,9.5,7,6.5,7.5,8,10,5.5,8.5', 'number_of_colors': 2, 'color_1': 'Sail/Sail/Black', 'color_2': 'Pink Blast/Sail/Chile Red', 'color_3': None, 'color_4': None, 'color_5': None, 'stars': 4.1, 'price': 10295, 'fitness': 1, 'comfort': 1, 'recommend': None}, {'link': 'https://www.nike.com/in/t/cortez-txt-shoes-1Tm7zf/DZ2795-001', 'brand': 'nike', 'shoe_name': 'Nike Cortez TXT', 'category': 'Women', 'style_or_product_code': 'Style: DZ2795-001', 'reviews': 1, 'number_of_sizes': 11, 'size': '6,5,9,9.5,7,6.5,7.5,8,10,5.5,8.5', 'number_of_colors': 3, 'color_1': 'Black/White', 'color_2': 'Midnight Navy/White', 'color_3': 'Fir/Sail/Light Silver/Sail', 'color_4': None, 'color_5': None, 'stars': 4, 'price': 8495, 'fitness': None, 'comfort': None, 'recommend': None}, {'link': 'https://www.nike.com/in/t/air-force-1-07-nn-shoes-nCJ6Wb/DV3808-101', 'brand': 'nike', 'shoe_name': "Nike Air Force 1 '07 NN", 'category': 'Women', 'style_or_product_code': 'Style: DV3808-101', 'reviews': 12, 'number_of_sizes': 11, 'size': '6,5,9,9.5,7,6.5,7.5,8,10,5.5,8.5', 'number_of_colors': 0, 'color_1': None, 'color_2': None, 'color_3': None, 'color_4': None, 'color_5': None, 'stars': 4.9, 'price': 9695, 'fitness': None, 'comfort': None, 'recommend': None}, {'link': 'https://www.nike.com/in/t/dunk-low-lx-nbhd-shoes-D1868r/FB7720-002', 'brand': 'nike', 'shoe_name': 'Nike Dunk Low LX NBHD', 'category': 'Women', 'style_or_product_code': 'Style: FB7720-002', 'reviews': 1, 'number_of_sizes': 11, 'size': '6,5,9,9.5,7,6.5,7.5,8,10,5.5,8.5', 'number_of_colors': 2, 'color_1': 'Light Smoke Grey/Photon Dust/Midnight Navy/White', 'color_2': 'Black/Black/Purple Ink', 'color_3': None, 'color_4': None, 'color_5': None, 'stars': 5, 'price': 10795, 'fitness': None, 'comfort': None, 'recommend': None}, {'link': 'https://www.nike.com/in/t/calm-mules-Pg5G3Z/FB2185-300', 'brand': 'nike', 'shoe_name': 'Nike Calm', 'category': 'Women', 'style_or_product_code': 'Style: FB2185-300', 'reviews': 0, 'number_of_sizes': 7, 'size': '9,6,5,7,8,10,11', 'number_of_colors': 3, 'color_1': 'Oil Green/Oil Green', 'color_2': 'Hemp/Hemp', 'color_3': 'Black/Black', 'color_4': None, 'color_5': None, 'stars': 0, 'price': 5695, 'fitness': None, 'comfort': None, 'recommend': None}, {'link': 'https://www.nike.com/in/t/air-humara-shoes-Hs4Qsh/FJ7098-701', 'brand': 'nike', 'shoe_name': 'Nike Air Humara', 'category': 'Men', 'style_or_product_code': 'Style: FJ7098-701', 'reviews': 8, 'number_of_sizes': 12, 'size': '12,9,9.5,7,7.5,8,10,10.5,11.5,13,11,8.5', 'number_of_colors': 5, 'color_1': 'Polar/Light Ultramarine/Deep Royal Blue/Buff Gold', 'color_2': 'Wheatgrass/Black/Wheatgrass/Yellow Ochre', 'color_3': 'Buff Gold/Bronzine/Velvet Brown/Buff Gold', 'color_4': 'Oil Green/Phantom/Light Bone/Malachite', 'color_5': 'Black/Metallic Silver/Black/Metalli ...

# %%
df1_columns = ["shoe_name", "category", "number_of_colors", "price"]
df2_columns = ["number_of_sizes", "color_1","color_2","color_3","color_4","color_5","style_or_product_code"]
df3_columns = ["reviews", "size", "comfort", "fitness", "recommend", "stars"]
nike_df1 = pd.DataFrame({key: d.get(key) for key in df1_columns} for d in nike_details)
nike_df2 = pd.DataFrame({key: d.get(key) for key in df2_columns} for d in nike_details)
nike_df3 = pd.DataFrame({key: d.get(key) for key in df3_columns} for d in nike_details)

print(nike_df1)
print("\n")

print(nike_df2)
print("\n")

print(nike_df3)
print("\n")
# Out:
#                             shoe_name category  number_of_colors  price
# 0              Nike Cortez 23 Premium    Women                 0   9695
# 1                 Nike P-6000 Premium      Men                 0  10795
# 2                 Air Jordan 1 Low SE    Women                 2  10295
# 3                     Nike Cortez TXT    Women                 3   8495
# 4             Nike Air Force 1 '07 NN    Women                 0   9695
# 5               Nike Dunk Low LX NBHD    Women                 2  10795
# 6                           Nike Calm    Women                 3   5695
# 7                     Nike Air Humara      Men                 5  14995
# 8                 Nike P-6000 Premium      Men                 0  10795
# 9              Nike Court Vision Alta    Women                 5   5995
# 10                        Nike Cortez    Women                 5   7495
# 11                 Nike Zoom Vomero 5      Men                 2  14995
# 12               Nike Air Force 1 '07    Women                 0  10795
# 13        Nike Air Force 1 '07 EasyOn    Women                 0   9695
# 18                                         None     Style: FV1176-247
# 19                     White/Summit White/Black     Style: DZ2628-103
# 20                                         None     Style: DM4044-102
# 21       Pink Oxford/Pearl Pink/White/Wolf Grey     Style: DH9523-105
# 22                                         None     Style: FB2269-103
# 23                                         None     Style: FB8825-001
# 24                                         None     Style: BV1358-001
# 25                                         None     Style: FV1166-200
# 26                                         None     Style: FD3598-001
# 27                                         None     Style: DX2931-200
# 28  Black/Metallic Silver/Black/Metallic Silver     Style: FJ7098-400
# 29                                         None     Style: FB9891-300
# 30              Fireberry/Fireberry/Fierce Pink     Style: DD8959-600
# 31                                         None     Style: FD8683-100
# 32                                         None     Style: DM4044-400
# 33                                         None     Style: FQ8107-133
# 34                                         None     Style: BV1358-003
# 35                   Lucky Green/White/Aquatone     Style: DC0774-080
# 36                                         None     Style: FD0736-101
# 37          Design your own Nike By You product     Style: DN1791-100
# 38          Phantom/Phantom/Light Orewood Brown     Style: DR9761-100
# 39                                         None     Style: FD0555-100
# 40          Phantom/Phantom/Light Orewood Brown     Style: DR9761-800
# 41                                         None     Style: FB9149-001
# 42                                         None     Style: FD3598-002
# 43                                         None     Style: CI0919-116
# 44          Design your own Nike By You product     Style: DJ0292-101
# 45                                         None     Style: DH3158-101
#
#
#     reviews                                              size  comfort  \
# 0         0                  6,5,9,9.5,7,6.5,7.5,8,10,5.5,8.5      NaN
# 1         9      12,9,9.5,12.5,7,7.5,8,10,10.5,11.5,13,11,8.5      NaN
# 2         9                  6,5,9,9.5,7,6.5,7.5,8,10,5.5,8.5     1.00
# 3         1                  6,5,9,9.5,7,6.5,7.5,8,10,5.5,8.5      NaN
# 4        12                  6,5,9,9.5,7,6.5,7.5,8,10,5.5,8.5      NaN
# 5         1                  6,5,9,9.5,7,6.5,7.5,8,10,5.5,8.5      NaN
# 6         0                                   9,6,5,7,8,10,11      NaN
# 7         8           12,9,9.5,7,7.5,8,10,10.5,11.5,13,11,8.5      NaN
# 8         5      12,9,9.5,12.5,7,7.5,8,10,10.5,11.5,13,11,8.5      NaN
# 9        64                  6,5,9,9.5,7,6.5,7.5,8,10,5.5,8.5      NaN
# 10       39                 6,9,9.5,7,6.5,7.5,8,10,5.5,11,8.5      NaN
# 11        0           12,9,9.5,7,7.5,8,10,10.5,11.5,13,11,8.5      NaN
# 12       25                  6,5,9,9.5,7,6.5,7.5,8,10,5.5,8.5      NaN
# 13      119               6,5,9,9.5,7,6.5,7.5,8,10,5.5,11,8.5      NaN
# 14       60                       6,9,9.5,7,6.5,7.5,8,5.5,8.5      NaN
# 15        1                      6,5,9,9.5,7,6.5,7.5,8,10,8.5      NaN
# 16       39                 6,9,9.5,7,6.5,7.5,8,10,5.5,11,8.5      NaN
# 17      108                  6,5,9,9.5,7,6.5,7.5,8,10,5.5,8.5      NaN
# 18        0                       6,9,9.5,7,6.5,7.5,8,5.5,8.5      NaN
# 19       65                 6,9,9.5,7,6.5,7.5,8,10,5.5,11,8.5      NaN
# 20       37      12,9,9.5,12.5,7,7.5,8,10,10.5,11.5,13,11,8.5     1.00
# 21       71                  6,5,9,9.5,7,6.5,7.5,8,10,5.5,8.5      NaN
# 22        2  12,6,5,9,9.5,7,6.5,7.5,8,10,10.5,11.5,5.5,11,8.5      NaN
# 23        0                  6,5,9,9.5,7,6.5,7.5,8,10,5.5,8.5      NaN
# 24       24      12,9,9.5,12.5,7,7.5,8,10,10.5,11.5,13,11,8.5     2.00
# 25        0                       6,9,9.5,7,6.5,7.5,8,5.5,8.5      NaN
# 26        8      12,9,9.5,12.5,7,7.5,8,10,10.5,11.5,13,11,8.5      NaN
# 27       24               6,5,9,9.5,7,6.5,7.5,8,10,5.5,11,8.5      NaN
# 28        8           12,9,9.5,7,7.5,8,10,10.5,11.5,13,11,8.5      NaN
# 29       16                           6,9,7,6.5,7.5,8,5.5,8.5      NaN
# 30      875  12,6,5,9,9.5,7,6.5,7.5,8,10,10.5,11.5,5.5,11,8.5     1.70
# 31        1                  6,5,9,9.5,7,6.5,7.5,8,10,5.5,8.5     2.00
# 32       37      12,9,9.5,12.5,7,7.5,8,10,10.5,11.5,13,11,8.5     1.00
# 33        0                     6,5,9,9.5,7,6.5,7.5,8,5.5,8.5      NaN
# 34       24      12,9,9.5,12.5,7,7.5,8,10,10.5,11.5,13,11,8.5     2.00
# 35      374                  6,5,9,9.5,7,6.5,7.5,8,10,5.5,8.5     1.33
# 36       10                       6,9,9.5,7,6.5,7.5,8,5.5,8.5      NaN
# 37       39                 6,9,9.5,7,6.5,7.5,8,10,5.5,11,8.5      NaN
# 38       60                       6,9,9.5,7,6.5,7.5,8,5.5,8.5      NaN
# 39        0                  6,5,9,9.5,7,6.5,7.5,8,10,5.5,8.5      NaN
# 40       60                       6,9,9.5,7,6.5,7.5,8,5.5,8.5      NaN
# 41        0           12,9,9.5,7,7.5,8,10,10.5,11.5,13,11,8.5      NaN
# 42        8      12,9,9.5,12.5,7,7.5,8,10,10.5,11.5,13,11,8.5      NaN
# 43      457  12,6,5,9,9.5,7,6.5,7.5,8,10,10.5,11.5,5.5,11,8.5     1.70
# 44      173          6,5,9,9.5,7,6.5,7.5,8,10,10.5,5.5,11,8.5      NaN
# 45       48  12,6,5,9,9.5,7,6.5,7.5,8,10,10.5,11.5,5.5,11,8.5     2.00
#
#     fitness recommend  stars
# 0       NaN      None    0.0
# 1       NaN      None    5.0
# 2      1.00      None    4.1
# 3       NaN      None    4.0
# 4       NaN      None    4.9
# 5       NaN      None    5.0
# 6       NaN      None    0.0
# 7       NaN      None    4.8
# 8       NaN      None    5.0
# 9       NaN      None    4.1
# 10      NaN      None    4.4
# 11      NaN      None    0.0
# 12      NaN      None    4.6
# 13      NaN      None    4.6
# 14      NaN      None    4.3
# 15      NaN      None    5.0
# 16      NaN      None    4.4
# 17      NaN      None    4.4
# 18      NaN      None    0.0
# 19      NaN      None    4.6
# 20     0.50      None    4.6
# 21      NaN      None    4.6
# 22      NaN      None    4.5
# 23      NaN      None    0.0
# 24     1.00      None    4.8
# 25      NaN      None    0.0
# 26      NaN      None    4.1
# 27      NaN      None    4.4
# 28      NaN      None    4.8
# 29      NaN      None    4.9
# 30     1.30      None    4.7
# 31     1.00      None    5.0
# 32     0.50      None    4.6
# 33      NaN      None    0.0
# 34     1.00      None    4.8
# 35     1.00      None    4.8
# 36      NaN      None    4.9
# 37      NaN      None    4.4
# 38      NaN      None    4.3
# 39      NaN      None    0.0
# 40      NaN      None    4.3
# 41      NaN      None    0.0
# 42      NaN      None    4.1
# 43     1.11      None    4.8
# 44      NaN      None    4.5
# 45     1.00      None    4.7
